# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/vvhem/Jupyter_content/Madura_Internship/Main_file.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df=df.drop(df.columns[[0]],axis=1)

# %%
df.head()
# Out:
#    Age   BMI Diabetes     Hypertension  Albumin to Creatinine Ratio  \
# 0   26  19.7      yes  well-controlled                        174.6
# 1   55  23.0      yes  well-controlled                        298.7
# 2   62  22.4      yes               No                        208.0
# 3   70  27.6       No  well-controlled                        256.9
# 4   85  26.9       No  well-controlled                         28.8
#
#    Glomerular Filtration Rate  Serum Creatinine Level  Hemoglobin Level  \
# 0                        21.0                     3.2               8.2
# 1                        16.7                     3.2               8.4
# 2                        17.3                     3.2               7.0
# 3                        15.1                     3.7               8.3
# 4                        13.1                     8.0               6.6
#
#    Serum Calcium Level  Serum Phosphate Level  ...  Serum Sodium Level  \
# ...

# %%
df['Diabetes']=le.fit_transform(df['Diabetes'])

# %%
df['Hypertension']=le.fit_transform(df['Hypertension'])

# %%
df.head()
# Out:
#    Age   BMI  Diabetes  Hypertension  Albumin to Creatinine Ratio  \
# 0   26  19.7         1             1                        174.6
# 1   55  23.0         1             1                        298.7
# 2   62  22.4         1             0                        208.0
# 3   70  27.6         0             1                        256.9
# 4   85  26.9         0             1                         28.8
#
#    Glomerular Filtration Rate  Serum Creatinine Level  Hemoglobin Level  \
# 0                        21.0                     3.2               8.2
# 1                        16.7                     3.2               8.4
# 2                        17.3                     3.2               7.0
# 3                        15.1                     3.7               8.3
# 4                        13.1                     8.0               6.6
#
#    Serum Calcium Level  Serum Phosphate Level  ...  Serum Sodium Level  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
con=confusion_matrix(y_test,y_pred)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)

# %%
print(acc)
# Out:
# 0.999

# %%
from sklearn import tree

# %%
import matplotlib.pyplot as plt

# %%
plot=plt.figure(figsize=(12,8),dpi=500)
_=tree.plot_tree(classifier,feature_names=df.columns,class_names=['Progression','Regression'],filled=True,fontsize=6)

# %%
plot.savefig('model_graph.jpg')

# %%
for i in df:
    print(i," ",df[i][3002])
# Out:
# Age   68
# BMI   27.2
# Diabetes   0
# Hypertension   0
# Albumin to Creatinine Ratio   251.9
# Glomerular Filtration Rate   81.8
# Serum Creatinine Level   1.5
# Hemoglobin Level   12.8
# Serum Calcium Level   9.3
# Serum Phosphate Level   2.9
# Serum Potassium Level   4.6
# Serum Sodium Level   141
# Serum Albumin Level   4.4
# Serum Bicarbonate Level   28
# Stage   2
# Med_1   0
# Med_2   0
# Med_3   1
# Med_4   1
# Med_5   0
# group   0
